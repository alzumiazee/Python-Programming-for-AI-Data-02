# %%
# !ruff check calculator.py
# Out:
# All checks passed!

# %%
# !ruff check calculator.py --fix
# Out:
# Found 2 errors (2 fixed, 0 remaining).

# %%
import math
import random

StudentName="Rahim"
Age=22

Marks=[80,90,95]

Average=sum(Marks)/len(Marks)

print(StudentName,Average)

# %%
# !ruff check student02.py
# Out:
# student02.py:1:1: E902 The system cannot find the file specified. (os error 2)
# Found 1 error.

# %%
# !ruff check C:\\test\\student02.py
# Out:
# C:\test\student02.py:1:8: F401 [*] `math` imported but unused
#   |
# 1 | import math
#   |        ^^^^ F401
# 2 | import random
#   |
#   = help: Remove unused import: `math`
#
# C:\test\student02.py:2:8: F401 [*] `random` imported but unused
#   |
# 1 | import math
# 2 | import random
#   |        ^^^^^^ F401
# 3 |
# 4 | StudentName="Rahim"
#   |
#   = help: Remove unused import: `random`
#
# Found 2 errors.
# [*] 2 fixable with the `--fix` option.
